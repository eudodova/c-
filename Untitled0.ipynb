# %% [markdown]
# <a href="https://colab.research.google.com/github/eudodova/c-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Paskaidrojums, kas te notiek - lai vēlāk atcerētos

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# komentars
